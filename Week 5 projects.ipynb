# %% [markdown]
# # Project 1

# %%
forbidden_letters = ["t", "s", "o", "i"]
word = input("Enter your word: ")

def avoids():
    for i in range(len(list)):
        if list != forbidden:
            print("True")
   
    return(avoids)
# Out:
# Enter your word: cheese

# %% [markdown]
# # Project 2

# %%
import math
print("Welcome to my game of numbers")
p_1 = int(input("P_1, enter your number: "))
p_2 = int(input("P_2, Enter your number: "))

num = int(input("Enter a number: ")
if (num % 2) == 0:
    num is even
else:
    num is odd

          if winner =

# %% [markdown]
# # Project 4

# %%
distance = int(input("Enter your distance: "))
time = int(input("Enter your time: "))
speed = str((distance/time))
print("Your speed is " +speed)
# Out:
# Enter your distance: 50
# Enter your time: 2
# Your speed is 25.0

# %%
def avoids(strg, word):
    for letter in strg:
        if letter in word:
            return False;
    return True;

fin = open('words.txt')
def No_Contain(strg):
    count_word_no_contain = 0;
    for line in fin:
        result = avoids(strg, line.strip());
        if(result == True):
            count_word_no_contain += 1;
            print(line.strip());
    return count_word_no_contain;

print(avoids("HUY STRAUSS", "LION"));
strg = "lion king";
print("The number of words doesn’t have the letters of the string", strg, "is: ", No_Contain(strg));
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-efa9b1fd7c86> in <module>
#       5     return True;
#       6
# ----> 7 fin = open('words.txt')
#       8 def No_Contain(strg):
#       9     count_word_no_contain = 0;
#
# FileNotFoundError: [Errno 2] No such file or directory: 'words.txt'

# %%
forbidden=input("Enter the forbidden characters: ")  
fin=open("words.txt")  

def avoids():    
    for letter in fin:    # Searches the letter in the file #
        word=letter.strip()    
        if forbidden not in word:    #If forbidden char is not in the file#
            print(word)    
print(avoids())
# Out:
# Enter the forbidden characters: aeiou
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-817e7d239651> in <module>
#       1 forbidden=input("Enter the forbidden characters: ")
# ----> 2 fin=open("words.txt")
#       3
#       4 def avoids():
#       5     for letter in fin:    # Searches the letter in the file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'words.txt'

# %%
import pandas

# %%
p = pandas.read_excel("Student_Info.xlsx")

# %%
p
# Out:
#     Student ID First Name  Last Name  Level        Department       Phone  \
# 0            1     Rotimi    Adeleke    100        Mechanical  8083939412
# 1            2      Susan      Moses    200        Electrical  9083837383
# 2            3     Edward  Durojaiye    100        Mechanical  7083737373
# 3            4     Sandra    Awoyaya    200        Mechanical  8083129420
# 4            5       Dubi    Lalekan    100  Computer Science  9095871939
# 5            6      Idris     Momodu    200  Computer Science  8083773716
# 6            7     Latifa      Shehu    100        Electrical  7072748827
# 7            8     Martha    Lazarus    100        Mechanical  9092434553
# 8            9     Godwin     Saheid    200        Electrical  8082747572
# 9           10    Rukayat     Ahmadu    100  Computer Science  8058373945
# 10          11      Adam         Ali    100  Computer Science  7073373727
# 11          12    Abiola     Martins    200        Mechanical  8073737372
# 12          13    Adewale   Williams    100        Mechanical  9093837473
# 13          14     Loveth     Derele    100  Computer Science  8031231822
# 14          15      Adele      Smith    100        Electrical  8083737327
# 15          16     Gloria      Ebong    200  Computer Science  9048484821
# 16          17       Tega      Alile    100        Mechanical  9038389221
# 17          18        Uyi     Osagie    200  Computer Science  7083838221
# 18          19     Fatima  Gbemisola    100        Mechanical  8053293133
# 19          20       Aliu   Mustapha    200        Electrical  8048392822
#
#                      email
# 0     r.adeleke@pau.edu.ng
# 1       s.moses@pau.edu.ng
# 2   e.durojaiye@pau.edu.ng
# 3     s.awoyaya@pau.edu.ng
# 4     d.lalekan@pau.edu.ng
# 5      i.momodu@pau.edu.ng
# 6       l.shehu@pau.edu.ng
# 7     m.lazarus@pau.edu.ng
# 8      g.saheid@pau.edu.ng
# 9      r.ahmadu@pau.edu.ng
# 10        a.ali@pau.edu.ng
# 11    a.martins@pau.edu.ng
# 12   a.williams@pau.edu.ng
# 13     l.derele@pau.edu.ng
# 14      a.smith@pau.edu.ng
# 15      g.ebong@pau.edu.ng
# 16      t.alile@pau.edu.ng
# 17     u.osagie@pau.edu.ng
# 18  f.gbemisola@pau.edu.ng
# 19   a.mustapha@pau.edu.ng
